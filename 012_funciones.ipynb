# %% [markdown]
# <a href="https://colab.research.google.com/github/trblnyx/curso-2026-1/blob/trblnyx/012_funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creando funciones

# %%
def suma(num1, num2):
    """ Documentación de la función """
    return num1 + num2

# %%
suma(2,3)
# Out:
# 5

# %%
suma(3.1416,2.7183)
# Out:
# 5.8599

# %%
suma("Hola ","Mundo")
# Out:
# 'Hola Mundo'
