# %% [markdown]
# <a href="https://colab.research.google.com/github/trblnyx/curso-2026-1/blob/trblnyx/notebooks/011_bloques_control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bloques de Control

# %%
colores = ["rojo","verde","azul"]

# %%
personas = ["Hugo","Paco","Luis"]

# %% [markdown]
# ## for

# %%
for foo in range(6):
  print(foo)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # if else elif
